# %% [markdown]
# <a href="https://colab.research.google.com/github/irtushar/Python/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Print

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(12,12.5)
# Out:
# 12 12.5

# %%
print("Hello! Tushar")
# Out:
# Hello! Tushar

# %% [markdown]
# If

# %%
if 5>2:
 print("True")
# Out:
# True

# %%
if 2<5:
  print("False")
# Out:
# False

# %%
if 5<=5:
  print("True")
# Out:
# True

# %% [markdown]
# Variables

# %%
x=5
y="Hello World"
print(x,y)
# Out:
# 5 Hello World

# %%
x="Hello"
x=5
print(x)
# Out:
# 5

# %%
x = 5
y = "John"
print(type(x)) #type means which category data(int,float,string{})
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x, y, z)
print(y)
print(z)
# Out:
# Orange Banana Cherry
# Banana
# Cherry

# %%
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x, y, z)
print(y)
print(z)
# Out:
# apple banana cherry
# banana
# cherry

# %%
x = "Python"
y = "is"
z = "awesome"
print(x, y, z)
# Out:
# Python is awesome

# %%
x = "Python "
y = "is "
z = "awesome"
print(x + y + z)
# Out:
# Python is awesome

# %%
x = 5
y = 10
print(x + y)
# Out:
# 15

# %%
x = 5
y = "John"
print(x + y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-00c66e4310ff> in <cell line: 3>()
#       1 x = 5
#       2 y = "John"
# ----> 3 print(x + y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x = 5
y = "John"
print(x , y)
# Out:
# 5 John

# %%
x = "awesome" # we deaclear global variable outside the  function

def myfunc():
  x = "fantastic"
  print("Python is " + x)

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
# Python is awesome

# %%
def myfunc():
  global x #if we deaclear global variable inside function we should use global key word
  x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic

# %%
x = "awesome"

def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic

# %%
x = "awesome" #To change the value of a global variable inside a function, refer to the variable by using the global keyword

def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic

# %% [markdown]
# Built-in Data Types
# Text Type:	      str
#
# Numeric Types:	  int, float, complex
#
# Sequence Types:	  list, tuple, range
#
# Mapping Type:   	dict
#
# Set Types:	      set, frozenset
#
# Boolean Type:    	bool
#
# Binary Types:	    bytes, bytearray, memoryview
#
# None Type:	      NoneType

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %%
x = 5.5
print(type(x))
# Out:
# <class 'float'>

# %%
x = "Hello"
print(type(x))
# Out:
# <class 'str'>

# %%
x = 5j
print(type(x))
# Out:
# <class 'complex'>

# %%
x = ["apple", "banana", "cherry"] # here we use third bracket
print(type(x))
# Out:
# <class 'list'>

# %%
x = x = ("apple", "banana", "cherry") # here we use first bracket
print(type(x))
# Out:
# <class 'tuple'>

# %%
x = range(6)
print(type(x))
# Out:
# <class 'range'>

# %%
x = {"name" : "John", "age" : 36} #here we use : and second bracket
print(type(x))
# Out:
# <class 'dict'>

# %%
x = {"apple", "banana", "cherry"}
print(type(x))
# Out:
# <class 'set'>

# %%
x = frozenset({"apple", "banana", "cherry"})
print(type(x))
# Out:
# <class 'frozenset'>

# %%
x = True
print(type(x))
# Out:
# <class 'bool'>

# %%
x = b"Hello"
print(type(x))
# Out:
# <class 'bytes'>

# %%
x = bytearray(5)
print(type(x))
# Out:
# <class 'bytearray'>

# %%
x = memoryview(bytes(5))
print(type(x))
# Out:
# <class 'memoryview'>

# %%
x = None
print(type(x))
# Out:
# <class 'NoneType'>

# %% [markdown]
# Python Numbers

# %%
x = 1    # int
y = 2.8  # float
z = 1j   # complex
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
x = 1
y = 35656222554887711
z = -3255522

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x = 1.10
y = 1.0
z = -35.59

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x = 35e3
y = 12E4
z = -87.7e100

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x = 3+5j
y = 5j
z = -5j

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
x = 1    # int
y = 2.8  # float
z = 1j   # complex

#convert from int to float:
a = float(x)

#convert from float to int:
b = int(y)

#convert from int to complex:
c = complex(x)

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 1.0
# 2
# (1+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
import random

print(random.randrange(1, 10))
# Out:
# 2
